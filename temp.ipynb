# %%
import datetime
from pprint import pprint

tickers = ['MSFT','MMM', 'AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CVX', 'CSCO', 'KO']

column_name = 'Close'
interval = '1d'

start_date = datetime.datetime(2020,1,1)
end_date = datetime.datetime(2024,1,1)

# %%
# test data fetching
from src.datasource.yahoodata import YahooDataSource
main_data = YahooDataSource(tickers,start_date,end_date,columns=[column_name],interval=interval)
data = main_data.get_data()
main_data.get_data_by_frequency(start_date,end_date,'1d').ffill()
# Out:
# Adding MSFT to the data source
# Getting data for MSFT
# Adding MMM to the data source
# Getting data for MMM
# Adding AXP to the data source
# Getting data for AXP
# Adding AMGN to the data source
# Getting data for AMGN
# Adding AAPL to the data source
# Getting data for AAPL
# Adding BA to the data source
# Getting data for BA
# Adding CAT to the data source
# Getting data for CAT
# Adding CVX to the data source
# Getting data for CVX
# Adding CSCO to the data source
# Getting data for CSCO
# Adding KO to the data source
# Getting data for KO
#                   MSFT         MMM         AXP        AMGN        AAPL  \
# Date
# 2020-01-03  152.295425  123.211136  117.029076  207.779266   72.251114
# 2020-01-04  152.295425  123.211136  117.029076  207.779266   72.251114
# 2020-01-05  152.295425  123.211136  117.029076  207.779266   72.251114
# 2020-01-06  152.689072  123.328476  116.521889  209.373734   72.826843
# 2020-01-07  151.296860  122.831383  115.911392  207.404556   72.484337
# ...                ...         ...         ...         ...         ...
# 2023-12-25  373.215424   86.848938  183.853470  279.967377  193.091385
# 2023-12-26  373.295135   88.302818  184.239868  279.711182  192.542816
# 2023-12-27  372.707275   88.817398  185.329666  282.302399  192.642548
# 2023-12-28  373.912842   89.593346  186.062836  284.203918  193.071426
# 2023-12-29  374.670074   89.291122  185.607086  283.770416  192.024185
#
#                     BA         CAT         CVX       CSCO         KO
# Date
# 2020-01-03  330.791901  133.486633   98.972771  41.370991  47.516586
# 2020-01-04  330.791901  133.486633   98.972771  41.370991  47.516586
# 2020-01-05  330.791901  133.486633   98.972771  41.370991  47.516586
# 2020-01-06  331.766083  133.396729   98.637444  41.518646  47.499210
# 2020-01-07  335.285156  131.634155   97.377876  41.249390  47.134304
# ...                ...         ...         ...        ...        ...
# 2023-12-25  260.440002  286.803223  147.925827  48.881687  57.411739
# 2023-12-26  262.790009  292.008698  149.257706  49.067101  57.648003
# 2023-12-27  262.100006  294.468170  148.768051  49.223240  57.795666
# 2023-12-28  260.350006  293.243378  146.672318  49.262276  57.835045
# 2023-12-29  260.660004  292.048218  146.074921  49.301311  58.012238
#
# [1457 rows x 10 columns]

# %%
# test strategy
from src.algorithms.strategy import CvarMretOpt, EqualyWeighted, MeanSemidevOpt
equalyWeighted = EqualyWeighted()
cvarMretOpt = CvarMretOpt(1.2)
meanSemidevOpt = MeanSemidevOpt(4)

# %%
# test backtest
from src.backtest.backtest import BackTest

equalyWeighted_bt = BackTest(main_data, equalyWeighted)
equalyWeighted_bt.backtest(start_date, end_date, 12, 1, '1MS')
equalyWeighted_bt.plot_portfolio_returns()
pprint(equalyWeighted_bt.get_summary())

cvarMretOpt_bt = BackTest(main_data, cvarMretOpt)
cvarMretOpt_bt.backtest(start_date, end_date, 12, 1, '1MS')
cvarMretOpt_bt.plot_portfolio_returns()
pprint(cvarMretOpt_bt.get_summary())

meanSemidevOpt_bt = BackTest(main_data, meanSemidevOpt)
meanSemidevOpt_bt.backtest(start_date, end_date, 12, 1, '1MS')
meanSemidevOpt_bt.plot_portfolio_returns()
pprint(meanSemidevOpt_bt.get_summary())
# Out:
# e:\Projects\quant\portfolio-analysis-using-generative-adversarial-networks\src\backtest\backtest.py:87: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   portfolio_returns = self.portfolio_value.pct_change().dropna().values
# e:\Projects\quant\portfolio-analysis-using-generative-adversarial-networks\src\backtest\backtest.py:73: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   portfolio_returns = self.portfolio_value.pct_change().dropna().values
# Adding ^GSPC to the data source
# Getting data for ^GSPC
# {'Alpha': 0.00016532676094194336,
#  'Beta': 0.8766197600893791,
#  'Calmar Ratio': 2.2020375741428952,
#  'Max Drawdown': -0.214806295525579,
#  'Mean Daily Return': 0.0003943226652762072,
#  'Sharpe Ratio': 0.04433089935545294,
#  'Std Dev of Daily Return': 0.008894984559515899,
#  'Total Return': 0.4730115339097678}
# e:\Projects\quant\portfolio-analysis-using-generative-adversarial-networks\src\backtest\backtest.py:87: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   portfolio_returns = self.portfolio_value.pct_change().dropna().values
# e:\Projects\quant\portfolio-analysis-using-generative-adversarial-networks\src\backtest\backtest.py:73: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   portfolio_returns = self.portfolio_value.pct_change().dropna().values
# Adding ^GSPC to the data source
# Getting data for ^GSPC
# {'Alpha': 0.00027790500692040484,
#  'Beta': 0.6806259135859908,
#  'Calmar Ratio': 2.120258994847902,
#  'Max Drawdown': -0.26346516786580443,
#  'Mean Daily Return': 0.0004557022158026997,
#  'Sharpe Ratio': 0.045968064386837544,
#  'Std Dev of Daily Return': 0.00991345234743417,
#  'Total Return': 0.5586143919965842}
# e:\Projects\quant\portfolio-analysis-using-generative-adversarial-networks\src\backtest\backtest.py:87: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   portfolio_returns = self.portfolio_value.pct_change().dropna().values
# e:\Projects\quant\portfolio-analysis-using-generative-adversarial-networks\src\backtest\backtest.py:73: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   portfolio_returns = self.portfolio_value.pct_change().dropna().values
# Adding ^GSPC to the data source
# Getting data for ^GSPC
# {'Alpha': 4.581899033319684e-05,
#  'Beta': 0.7979501203618588,
#  'Calmar Ratio': 0.7241070623087295,
#  'Max Drawdown': -0.3393926894095663,
#  'Mean Daily Return': 0.000254264336588303,
#  'Sharpe Ratio': 0.024705118556361625,
#  'Std Dev of Daily Return': 0.010291969901226373,
#  'Total Return': 0.24575664329742009}
